# %%
import numpy as np   # Linear Algebra
import pandas as pd  # data processing, CSV file I/O
import os

# %%
os.chdir("C:\\Users\\batti\\Jupyter notebooks\\CSV.Jupyter notebook")     # chdir <---means change directory

# %%
data=pd.read_csv("UPSC_Raw_2022.csv")            #for reading files
data
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 575     NaN        NaN                          NaN
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
data.info()        

# it tells the no. of rows and columns and wt type of data in their
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S. NO.                     564 non-null    float64
#  1   ROLL NO                    564 non-null    float64
#  2   NAME                       564 non-null    object
#  3   FATHER'S NAME              564 non-null    object
#  4   D_O_B                      564 non-null    object
#  5   COMM                       564 non-null    object
#  6   GENDER                     564 non-null    object
#  7   EDUCATIONAL QUALIFICATION  564 non-null    object
#  8   TOTAL MARKS                564 non-null    float64
#  9   COMPLETE ADDRESS           578 non-null    object
#  10  Column11                   18 non-null     object
#  11  Column12                   19 non-null     object
#  12  Column13                   6 non-null      object
# ...

# %%
data.describe()
# Out:
#           S. NO.       ROLL NO  TOTAL MARKS
# count  564.00000  5.640000e+02   564.000000
# mean   620.50000  3.894696e+06   890.219858
# std    162.95705  2.472032e+06    34.680801
# min    339.00000  8.784700e+05   530.000000
# 25%    479.75000  1.217474e+06   869.000000
# 50%    620.50000  3.518008e+06   889.000000
# 75%    761.25000  6.311389e+06   913.000000
# max    902.00000  8.701356e+06   947.000000

# %%
data.head()          # it prints frst 5 lines
# Out:
#    S. NO.    ROLL NO                         NAME            FATHER'S NAME  \
# 0   354.0   883176.0            AMAR SINGH\nVERMA   RAMESH\nCHANDRA\nVERMA
# 1   372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR             T HARIPRASAD
# 2   377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR            S ASHOK KUMAR
# 3   382.0  1019768.0       GUNUPURU\nMADHU HARSHA  GUNUPURU\nSRINIVASA RAO
# 4   384.0  1024149.0         KANDULA KIRAN\nKUMAR          KANDULA\nRAMESH
#
#         D_O_B COMM GENDER EDUCATIONAL QUALIFICATION  TOTAL MARKS  \
# 0  10-09-1995  OBC   MALE                  B. TECH.        879.0
# 1  19-11-1993  OBC   MALE                  B. TECH.        895.0
# 2  04-12-1992  OBC   MALE                  B. TECH.        889.0
# 3  16-12-1996  OBC   MALE                  B. TECH.        907.0
# 4  06-04-1995  OBC   MALE                  B. TECH.        890.0
#
#                                     COMPLETE ADDRESS Column11 Column12  \
# ...

# %%
data.tail()           # it prints last 5 lines
# Out:
#      S. NO.    ROLL NO                        NAME  \
# 573   855.0  7001227.0             NICHIKETA ANAND
# 574   858.0  7005546.0                 MOHIT SINGH
# 575     NaN        NaN                         NaN
# 576   862.0  7105647.0          SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0  RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 573                DAVINDER\nANAND  03-04-1995  GEN   MALE
# 574            MOTI SINGH\nCHAUHAN  15-09-1993  GEN   MALE
# 575                            NaN         NaN  NaN    NaN
# 576                UDAIBHAN\nMEENA  05-05-1993   ST   MALE
# 577  KARSHANBHAI\nRAJABHAI\nRATHOD  04-02-1993  OBC   MALE
#
#     EDUCATIONAL QUALIFICATION  TOTAL MARKS  \
# 573                  B. TECH.        899.0
# 574                  B. TECH.        909.0
# 575                       NaN          NaN
# 576                  B. TECH.        835.0
# 577                      B.E.        870.0
#
# ...

# %%
data.isnull().sum()        #becoz of this fun we can know the null values 
#It just tells how many no. of null values are there but it doesn't remove any null values
# Out:
# S. NO.                        14
# ROLL NO                       14
# NAME                          14
# FATHER'S NAME                 14
# D_O_B                         14
# COMM                          14
# GENDER                        14
# EDUCATIONAL QUALIFICATION     14
# TOTAL MARKS                   14
# COMPLETE ADDRESS               0
# Column11                     560
# Column12                     559
# Column13                     572
# EMAIL ID                      14
# dtype: int64

# %%
data
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 575     NaN        NaN                          NaN
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S. NO.                     564 non-null    float64
#  1   ROLL NO                    564 non-null    float64
#  2   NAME                       564 non-null    object
#  3   FATHER'S NAME              564 non-null    object
#  4   D_O_B                      564 non-null    object
#  5   COMM                       564 non-null    object
#  6   GENDER                     564 non-null    object
#  7   EDUCATIONAL QUALIFICATION  564 non-null    object
#  8   TOTAL MARKS                564 non-null    float64
#  9   COMPLETE ADDRESS           578 non-null    object
#  10  Column11                   18 non-null     object
#  11  Column12                   19 non-null     object
#  12  Column13                   6 non-null      object
# ...

# %%
s=data.drop(['Column11','Column12','Column13'],axis='columns',inplace=True)      # delete specific null values and columns also
data
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 575     NaN        NaN                          NaN
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
data # print present data after remove null values
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 575     NaN        NaN                          NaN
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
data.info() #again check no. of columns becoz after using drop() it can reduce columns or rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   S. NO.                     564 non-null    float64
#  1   ROLL NO                    564 non-null    float64
#  2   NAME                       564 non-null    object
#  3   FATHER'S NAME              564 non-null    object
#  4   D_O_B                      564 non-null    object
#  5   COMM                       564 non-null    object
#  6   GENDER                     564 non-null    object
#  7   EDUCATIONAL QUALIFICATION  564 non-null    object
#  8   TOTAL MARKS                564 non-null    float64
#  9   COMPLETE ADDRESS           578 non-null    object
#  10  EMAIL ID                   564 non-null    object
# dtypes: float64(3), object(8)
# memory usage: 49.8+ KB

# %%
data.isnull().sum()
# Out:
# S. NO.                       14
# ROLL NO                      14
# NAME                         14
# FATHER'S NAME                14
# D_O_B                        14
# COMM                         14
# GENDER                       14
# EDUCATIONAL QUALIFICATION    14
# TOTAL MARKS                  14
# COMPLETE ADDRESS              0
# EMAIL ID                     14
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)  # It completely removes all the null values in the given data set

# %%
data
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 572   853.0  6907740.0                 ANAND SHARMA
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
#                 Finally  Remove all null values  ------------------------------>Data Preprocessing completed

# %%
data #now we have this data
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 572   853.0  6907740.0                 ANAND SHARMA
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
data=data.replace(['\n'," "],regex=True)    # here we remove the  "\n"  symbol

# %%
data
# Out:
#      S. NO.    ROLL NO                         NAME  \
# 0     354.0   883176.0            AMAR SINGH\nVERMA
# 1     372.0  1005284.0  TATIPAMULA\nJASWANTH\nKUMAR
# 2     377.0  1016394.0      SYDHUGARI\nPRANAV KUMAR
# 3     382.0  1019768.0       GUNUPURU\nMADHU HARSHA
# 4     384.0  1024149.0         KANDULA KIRAN\nKUMAR
# ..      ...        ...                          ...
# 572   853.0  6907740.0                 ANAND SHARMA
# 573   855.0  7001227.0              NICHIKETA ANAND
# 574   858.0  7005546.0                  MOHIT SINGH
# 576   862.0  7105647.0           SUNIL KUMAR\nMEENA
# 577   863.0  7200823.0   RATHOD KRUNAL\nKARSHANBHAI
#
#                      FATHER'S NAME       D_O_B COMM GENDER  \
# 0           RAMESH\nCHANDRA\nVERMA  10-09-1995  OBC   MALE
# 1                     T HARIPRASAD  19-11-1993  OBC   MALE
# 2                    S ASHOK KUMAR  04-12-1992  OBC   MALE
# 3          GUNUPURU\nSRINIVASA RAO  16-12-1996  OBC   MALE
# ...

# %%
s=display(data[data['TOTAL MARKS']>=946])
# Out:
#      S. NO.    ROLL NO                 NAME             FATHER'S NAME  \
# 85    350.0   882636.0       ANKUSH SOLANKI            VIRENDRA SINGH
# 98    520.0  1900448.0         JOEL ABRAHAM            ABRAHAM PHILIP
# 105   552.0  2104712.0     AKASH\nCHAUDHARY   RAJESH KUMAR\nCHAUDHARY
# 107   557.0  2201079.0  VIJAY RAGHAV\nGOYAL               JAI PRAKASH
# 115   584.0  2613767.0        SULABH TIWARI   KARUNA\nSHANKAR\nTIWARI
# 120   603.0  3403054.0         VIPUL SHARMA       VED PARKASH\nSHARMA
# 141   789.0  6600308.0  GARUD SANKET\nSUNIL  SUNIL\nPARASHARAM\nGARUD
# 260   439.0  1119927.0       ROOPALI SURANA             RAKESH SURANA
# 300   742.0  6303905.0       SALONI CHHABRA        INDERJEET\nCHHABRA
# 313   887.0  7815581.0     ANOUSHKA\nSHARMA              SUNIL SHARMA
#
#           D_O_B COMM  GENDER EDUCATIONAL QUALIFICATION  TOTAL MARKS  \
# 85   28-05-1992  GEN    MALE                  B. TECH.        946.0
# ...

# %%
display(data[data['COMM']=='ST'])
# Out:
#      S. NO.    ROLL NO                         NAME          FATHER'S NAME  \
# 158   374.0  1010435.0         SAICHAITANYA\nJADHAV              GOVINDRAO
# 159   386.0  1029040.0      KETHAVATH\nVISHAL SINGH           K AMAR SINGH
# 161   397.0  1040037.0          BHUKYA CHARAN\nNAIK         BHUKYA\nRAMESH
# 162   411.0  1100761.0          VIKASH KUMAR\nMEENA     MOHAR SINGH\nMEENA
# 163   417.0  1105152.0                AVDHESH MEENA     SHARWAN LAL\nMEENA
# 164   418.0  1105522.0         AVINASH KUMAR\nMEENA        RAM DHAN\nMEENA
# 166   431.0  1114953.0         JASWANT SINGH\nMEENA         RAMKESH\nMEENA
# 167   433.0  1115310.0           RAHUL KUMAR\nMEENA      CHHOTE LAL\nMEENA
# 168   434.0  1115950.0                 DEEPAK MEENA         SHRIRAM\nMEENA
# 169   452.0  1132747.0        YESHWANT\nKUMAR MEENA       BHERU LAL\nMEENA
# 185   680.0  5415756.0                    AMAN NEGI          ROOP RAM NEGI
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use("fivethirtyeight")

# %%
ST=data[data.COMM>='ST']

# %%
plt.bar(ST['NAME'],ST['TOTAL MARKS'])
plt.title('ST Students Marks in UPSC')
plt.ylabel('Marks')
plt.xlabel('Names')
plt.gcf().set_size_inches(20,5)
plt.xticks(rotation=90)
plt.show()
