# %%
import pandas as pd
import numpy as np  
import os

# %%
os.chdir("C:\\Users\\batti\\Jupyter notebooks\\CSV.Jupyter notebook")

# %%
data=pd.read_csv("richest.csv")
data
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               101 non-null    object
#  1   NetWorth           101 non-null    object
#  2   Age                101 non-null    int64
#  3   Country/Territory  101 non-null    object
#  4   Source             101 non-null    object
#  5   Industry           101 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.9+ KB
# None

# %%
data.describe()
# Out:
#               Age
# count  101.000000
# mean    67.118812
# std     13.892651
# min     30.000000
# 25%     57.000000
# 50%     67.000000
# 75%     77.000000
# max     94.000000

# %%
data.head()  #it prints starting data upto 5 mem
# Out:
#                        Name          NetWorth  Age Country/Territory  \
# 0                 Elon Musk  $219,000,000,000   50     United States
# 1                Jeff Bezos  $171,000,000,000   58     United States
# 2  Bernard Arnault & family  $158,000,000,000   73            France
# 3                Bill Gates  $129,000,000,000   66     United States
# 4            Warren Buffett  $118,000,000,000   91     United States
#
#                Source               Industry
# 0       Tesla, SpaceX             Automotive
# 1              Amazon             Technology
# 2                LVMH       Fashion & Retail
# 3           Microsoft             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
data.tail()   # #it prints last data only5 mem
# Out:
#                      Name         NetWorth  Age Country/Territory  \
# 96       Vladimir Potanin  $17,300,000,000   61            Russia
# 97   Harold Hamm & family  $17,200,000,000   76     United States
# 98           Sun Piaoyang  $17,100,000,000   63             China
# 99     Luo Liguo & family  $17,000,000,000   66             China
# 100             Peter Woo  $17,000,000,000   75         Hong Kong
#
#               Source         Industry
# 96            metals  Metals & Mining
# 97         oil & gas           Energy
# 98   pharmaceuticals       Healthcare
# 99         chemicals    Manufacturing
# 100      real estate      Real Estate

# %%
data.isnull().sum() #check the null values position
# Out:
# Name                 0
# NetWorth             0
# Age                  0
# Country/Territory    0
# Source               0
# Industry             0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)       # 'drop' removes every null values

# %%
data.isnull().sum()      #if any null values will be there in data frst we can find the using drop function we can remove those null values
#again we can print that data so, in before a single null obs is there after drop it will be remove
# Out:
# Name                 0
# NetWorth             0
# Age                  0
# Country/Territory    0
# Source               0
# Industry             0
# dtype: int64

# %%
data
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
data=data.replace(['\$'," "],"",regex=True)    # <-----------------this line w2for removing   "$"  symbol

# %%
data
# Out:
#                       Name         NetWorth  Age Country/Territory  \
# 0                 ElonMusk  219,000,000,000   50      UnitedStates
# 1                JeffBezos  171,000,000,000   58      UnitedStates
# 2    BernardArnault&family  158,000,000,000   73            France
# 3                BillGates  129,000,000,000   66      UnitedStates
# 4            WarrenBuffett  118,000,000,000   91      UnitedStates
# ..                     ...              ...  ...               ...
# 96         VladimirPotanin   17,300,000,000   61            Russia
# 97       HaroldHamm&family   17,200,000,000   76      UnitedStates
# 98             SunPiaoyang   17,100,000,000   63             China
# 99         LuoLiguo&family   17,000,000,000   66             China
# 100               PeterWoo   17,000,000,000   75          HongKong
#
#                 Source             Industry
# 0         Tesla,SpaceX           Automotive
# 1               Amazon           Technology
# ...

# %%
#------------------------------->  <--------------------------
#def value_to_float(x):
 #   if 'K' in x:
  #      if len(x) >1:
   #         return float(x.replace('K',''))*0.000001
    #if 'M' in x:
     #   if len(x) >1:
      #      return float(x.replace('M',''))*1000
    #if 'B' in x:
       # if len(x) >1:
        #    return float(x.replace('B',''))*100000
#data['$ Last change']=data['$ Last change'].apply(value_to_float)

# %%
data["NetWorth"]=data["NetWorth"].replace("B",'',regex=True)

# %%
data
# Out:
#                       Name         NetWorth  Age Country/Territory  \
# 0                 ElonMusk  219,000,000,000   50      UnitedStates
# 1                JeffBezos  171,000,000,000   58      UnitedStates
# 2    BernardArnault&family  158,000,000,000   73            France
# 3                BillGates  129,000,000,000   66      UnitedStates
# 4            WarrenBuffett  118,000,000,000   91      UnitedStates
# ..                     ...              ...  ...               ...
# 96         VladimirPotanin   17,300,000,000   61            Russia
# 97       HaroldHamm&family   17,200,000,000   76      UnitedStates
# 98             SunPiaoyang   17,100,000,000   63             China
# 99         LuoLiguo&family   17,000,000,000   66             China
# 100               PeterWoo   17,000,000,000   75          HongKong
#
#                 Source             Industry
# 0         Tesla,SpaceX           Automotive
# 1               Amazon           Technology
# ...

# %%
data.head()
# Out:
#                     Name         NetWorth  Age Country/Territory  \
# 0               ElonMusk  219,000,000,000   50      UnitedStates
# 1              JeffBezos  171,000,000,000   58      UnitedStates
# 2  BernardArnault&family  158,000,000,000   73            France
# 3              BillGates  129,000,000,000   66      UnitedStates
# 4          WarrenBuffett  118,000,000,000   91      UnitedStates
#
#               Source             Industry
# 0       Tesla,SpaceX           Automotive
# 1             Amazon           Technology
# 2               LVMH       Fashion&Retail
# 3          Microsoft           Technology
# 4  BerkshireHathaway  Finance&Investments

# %%
data.dtypes
# Out:
# Name                 object
# NetWorth             object
# Age                   int64
# Country/Territory    object
# Source               object
# Industry             object
# dtype: object

# %%
display(data[data['Age']>=85])
# Out:
#                          Name         NetWorth  Age Country/Territory  \
# 4               WarrenBuffett  118,000,000,000   91      UnitedStates
# 20                CharlesKoch   60,000,000,000   86      UnitedStates
# 22              AmancioOrtega   59,600,000,000   86             Spain
# 31     FrançoisPinault&family   40,400,000,000   85            France
# 36                 LiKa-shing   34,800,000,000   93          HongKong
# 38                 LeeShauKee   32,600,000,000   94          HongKong
# 41                   JohnMars   31,700,000,000   86      UnitedStates
# 51  LeonardoDelVecchio&family   27,300,000,000   86             Italy
# 64              LeonardLauder   23,100,000,000   89      UnitedStates
# 75       RupertMurdoch&family   20,800,000,000   91      UnitedStates
# 83      ReinholdWuerth&family   19,000,000,000   86           Germany
#
#                   Source             Industry
# 4      BerkshireHathaway  Finance&Investments
# ...

# %%
display(data[data.Industry=='Healthcare'])
# Out:
#                       Name        NetWorth  Age Country/Territory  \
# 56         CyrusPoonawalla  24,300,000,000   80             India
# 72  ThomasFrist,Jr.&family  21,800,000,000   83      UnitedStates
# 90    JiangRensheng&family  17,700,000,000   68             China
# 93                LiXiting  17,600,000,000   71         Singapore
# 98             SunPiaoyang  17,100,000,000   63             China
#
#              Source    Industry
# 56         vaccines  Healthcare
# 72        hospitals  Healthcare
# 90         vaccines  Healthcare
# 93   medicaldevices  Healthcare
# 98  pharmaceuticals  Healthcare

# %%
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import figure
style.use('fivethirtyeight')

# %%
Healthcare=data[data.Industry=='Healthcare']

# %%
plt.bar(Healthcare['Name'],Healthcare['Age'])  # Here we must take categorical data and numerical data(categorical data i.e...,Name and num i.e.,Age)
plt.title('Richest persons data in Healthcare')    #title
plt.xlabel('Richest persons')
plt.ylabel('Billion $')
plt.gcf().set_size_inches(6, 5)   #gcf====great common figure (6,5),----size
plt.xticks(rotation=90)       #x-axis names eachone based on angle
plt.show()   #print
